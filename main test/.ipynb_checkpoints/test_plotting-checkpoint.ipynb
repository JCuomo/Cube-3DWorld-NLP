# %%
# %matplotlib notebook
import class_plot3Dsolution
import class_3Danimation

# %%
p = class_plot3Dsolution.PlotSolution()
p.plot("2", fps=10)
# Out:
# <img src="data:image/png;base64,..." width="959.9999791925608">
