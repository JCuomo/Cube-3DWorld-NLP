# %%
import sys, os
start_f = "start" #sys.argv[1]

# %%
try:
    if not os.path.exists("tests"):
        os.makedirs("tests")
except OSError:
    print ('Error: Creating "tests" folder..do it manually')

sentence = "'move red block on top of green block.'"
get_ipython().run_line_magic('run', "-i 'parser.py' $sentence 'goal'")
print("Goal parsed")
# Out:
# parsing: move red block on top of green block.
#
# Running spacy tokenizer.
# Dependency (DEP) tags:
# move:ROOT
# red:amod
# block:dobj
# on:prep
# top:pobj
# of:prep
# green:amod
# block:pobj
# .:punct
#
# Part of speech (POS) tags:
# move:VERB
# red:ADJ
# block:NOUN
# on:ADP
# top:NOUN
# of:ADP
# green:ADJ
# block:NOUN
# .:PUNCT
#
#      move
#   ____|_____
#  |    |     on
#  |    |     |
#  |    |    top
#  |    |     |
#  |    |     of
#  |    |     |
#  |  block block
#  |    |     |
#  .   red  green
#
#
# Block(s) in sentence:
# red block
# green block
#
# Command in sentence:
# on top of
# is red green on-top-of
# ['is red green on-top-of']
# Goal parsed

# %% [markdown]
# Change colors by block names in the "goal" file

# %%
get_ipython().run_line_magic('run', "-i 'part1_findGoal_v2.py'  $start_f 'goal'")
print("Goal defined")

get_ipython().run_line_magic('run', "-i 'part2_findStackMoves.py'")
print("Stacking relations solved")

get_ipython().run_line_magic('run', "-i 'part3_findPaths.py'")

# %%
# %matplotlib notebook
import class_plot3Dsolution
import class_3Danimation

p = class_plot3Dsolution.PlotSolution()
p.plot("", fps=30)
# Out:
# <img src="data:image/png;base64,..." width="479.9999895962804">
